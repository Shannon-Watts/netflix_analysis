# %% [markdown]
# # Netflix & Top Grossing Films ETL

# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\chisi\anaconda3\envs\pythondata\lib\site-packages (2.9.3)

# %% [markdown]
# ## Extract

# %%
csv_file = "netflix_titles.csv"
netflix_df = pd.read_csv(csv_file)
netflix_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
csv_file_1 = "imdb_top_1000.csv"
imdb_df = pd.read_csv(csv_file_1)
imdb_df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# ## Transform

# %%
# Clean netflix_df
netflix_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# We want to drop show_id, cast, country, date_added
del netflix_df['show_id']
del netflix_df['cast']
del netflix_df['country']
del netflix_df['date_added']
del netflix_df['rating']

# %%
# Rename columns 
netflix_df = netflix_df.rename(columns={"type":"genre"})
netflix_df = netflix_df.rename(columns={"duration":"runtime"})
netflix_df = netflix_df.rename(columns={"description":"overview"})

# %%
# Clean imdb_df
imdb_df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
# We want to drop Poster_link, Star1, Star2, Star3, Star4
del imdb_df['Poster_Link']
del imdb_df['Star1']
del imdb_df['Star2']
del imdb_df['Star3']
del imdb_df['Star4']
del imdb_df['Certificate']

# %%
# Rename columns 
imdb_df = imdb_df.rename(columns={"Series_Title":"title"})
imdb_df = imdb_df.rename(columns={"Released_Year":"release_year"})
imdb_df = imdb_df.rename(columns={"Runtime":"runtime"})
imdb_df = imdb_df.rename(columns={"Genre":"genre"})
imdb_df = imdb_df.rename(columns={"Overview":"overview"})
imdb_df = imdb_df.rename(columns={"Director":"director"})

# %%
# Merge dfs
netflix_imdb1 = pd.concat([netflix_df, imdb_df])
netflix_imdb1
# Out:
#                         genre                   title          director  \
# 0                       Movie    Dick Johnson Is Dead   Kirsten Johnson
# 1                     TV Show           Blood & Water               NaN
# 2                     TV Show               Ganglands   Julien Leclercq
# 3                     TV Show   Jailbirds New Orleans               NaN
# 4                     TV Show            Kota Factory               NaN
# ..                        ...                     ...               ...
# 995    Comedy, Drama, Romance  Breakfast at Tiffany's     Blake Edwards
# 996            Drama, Western                   Giant    George Stevens
# 997       Drama, Romance, War   From Here to Eternity    Fred Zinnemann
# 998                Drama, War                Lifeboat  Alfred Hitchcock
# 999  Crime, Mystery, Thriller            The 39 Steps  Alfred Hitchcock
#
#     release_year    runtime  \
# 0           2020     90 min
# 1           2021  2 Seasons
# 2           2021   1 Season
# 3           2021   1 Season
# 4           2021  2 Seasons
# ..           ...        ...
# 995         1961    115 min
# 996         1956    201 min
# 997         1953    118 min
# 998         1944     97 min
# 999         1935     86 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 1      International TV Shows, TV Dramas, TV Mysteries
# 2    Crime TV Shows, International TV Shows, TV Act...
# 3                               Docuseries, Reality TV
# 4    International TV Shows, Romantic TV Shows, TV ...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               overview  IMDB_Rating  \
# 0    As her father nears the end of his life, filmm...          NaN
# 1    After crossing paths at a party, a Cape Town t...          NaN
# 2    To protect his family from a powerful drug lor...          NaN
# 3    Feuds, flirtations and toilet talk go down amo...          NaN
# 4    In a city of coaching centers known to train I...          NaN
# ..                                                 ...          ...
# 995  A young New York socialite becomes interested ...          7.6
# 996  Sprawling epic covering the life of a Texas ca...          7.6
# 997  In Hawaii in 1941, a private is cruelly punish...          7.6
# 998  Several survivors of a torpedoed merchant ship...          7.6
# 999  A man in London tries to help a counter-espion...          7.6
#
#      Meta_score  No_of_Votes       Gross
# 0           NaN          NaN         NaN
# 1           NaN          NaN         NaN
# 2           NaN          NaN         NaN
# 3           NaN          NaN         NaN
# 4           NaN          NaN         NaN
# ..          ...          ...         ...
# 995        76.0     166544.0         NaN
# 996        84.0      34075.0         NaN
# 997        85.0      43374.0  30,500,000
# 998        78.0      26471.0         NaN
# 999        93.0      51853.0         NaN
#
# [9807 rows x 11 columns]

# %%
netflix_imdb1.loc[netflix_imdb1['release_year'] == 'PG']
# Out:
#                          genre      title    director release_year  runtime  \
# 966  Adventure, Drama, History  Apollo 13  Ron Howard           PG  140 min
#
#     listed_in                                           overview  IMDB_Rating  \
# 966       NaN  NASA must devise a strategy to return Apollo 1...          7.6
#
#      Meta_score  No_of_Votes        Gross
# 966        77.0     269197.0  173,837,933

# %%
netflix_imdb1.loc[966, 'release_year'] = 0

# %%
netflix_imdb1
# Out:
#                         genre                   title          director  \
# 0                       Movie    Dick Johnson Is Dead   Kirsten Johnson
# 1                     TV Show           Blood & Water               NaN
# 2                     TV Show               Ganglands   Julien Leclercq
# 3                     TV Show   Jailbirds New Orleans               NaN
# 4                     TV Show            Kota Factory               NaN
# ..                        ...                     ...               ...
# 995    Comedy, Drama, Romance  Breakfast at Tiffany's     Blake Edwards
# 996            Drama, Western                   Giant    George Stevens
# 997       Drama, Romance, War   From Here to Eternity    Fred Zinnemann
# 998                Drama, War                Lifeboat  Alfred Hitchcock
# 999  Crime, Mystery, Thriller            The 39 Steps  Alfred Hitchcock
#
#     release_year    runtime  \
# 0           2020     90 min
# 1           2021  2 Seasons
# 2           2021   1 Season
# 3           2021   1 Season
# 4           2021  2 Seasons
# ..           ...        ...
# 995         1961    115 min
# 996         1956    201 min
# 997         1953    118 min
# 998         1944     97 min
# 999         1935     86 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 1      International TV Shows, TV Dramas, TV Mysteries
# 2    Crime TV Shows, International TV Shows, TV Act...
# 3                               Docuseries, Reality TV
# 4    International TV Shows, Romantic TV Shows, TV ...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               overview  IMDB_Rating  \
# 0    As her father nears the end of his life, filmm...          NaN
# 1    After crossing paths at a party, a Cape Town t...          NaN
# 2    To protect his family from a powerful drug lor...          NaN
# 3    Feuds, flirtations and toilet talk go down amo...          NaN
# 4    In a city of coaching centers known to train I...          NaN
# ..                                                 ...          ...
# 995  A young New York socialite becomes interested ...          7.6
# 996  Sprawling epic covering the life of a Texas ca...          7.6
# 997  In Hawaii in 1941, a private is cruelly punish...          7.6
# 998  Several survivors of a torpedoed merchant ship...          7.6
# 999  A man in London tries to help a counter-espion...          7.6
#
#      Meta_score  No_of_Votes       Gross
# 0           NaN          NaN         NaN
# 1           NaN          NaN         NaN
# 2           NaN          NaN         NaN
# 3           NaN          NaN         NaN
# 4           NaN          NaN         NaN
# ..          ...          ...         ...
# 995        76.0     166544.0         NaN
# 996        84.0      34075.0         NaN
# 997        85.0      43374.0  30,500,000
# 998        78.0      26471.0         NaN
# 999        93.0      51853.0         NaN
#
# [9807 rows x 11 columns]

# %%
netflix_imdb1.loc[netflix_imdb1['title'] == 'Apollo 13']
# Out:
#                          genre      title    director release_year  runtime  \
# 966  Adventure, Drama, History  Apollo 13  Ron Howard            0  140 min
#
#     listed_in                                           overview  IMDB_Rating  \
# 966       NaN  NASA must devise a strategy to return Apollo 1...          7.6
#
#      Meta_score  No_of_Votes        Gross
# 966        77.0     269197.0  173,837,933

# %%
# Change null values
value = "not currently in IMDB top 1000"

netflix_imdb1['IMDB_Rating'] = netflix_imdb1['IMDB_Rating'].replace(np.nan, value)
netflix_imdb1['Meta_score'] = netflix_imdb1['Meta_score'].replace(np.nan, value)
netflix_imdb1['No_of_Votes'] = netflix_imdb1['No_of_Votes'].replace(np.nan, value)
netflix_imdb1['Gross'] = netflix_imdb1['Gross'].replace(np.nan, value)

netflix_imdb1.head()
# Out:
#      genre                  title         director release_year    runtime  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson         2020     90 min
# 1  TV Show          Blood & Water              NaN         2021  2 Seasons
# 2  TV Show              Ganglands  Julien Leclercq         2021   1 Season
# 3  TV Show  Jailbirds New Orleans              NaN         2021   1 Season
# 4  TV Show           Kota Factory              NaN         2021  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                             overview  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
#
#                       IMDB_Rating                      Meta_score  \
# 0  not currently in IMDB top 1000  not currently in IMDB top 1000
# 1  not currently in IMDB top 1000  not currently in IMDB top 1000
# 2  not currently in IMDB top 1000  not currently in IMDB top 1000
# 3  not currently in IMDB top 1000  not currently in IMDB top 1000
# 4  not currently in IMDB top 1000  not currently in IMDB top 1000
#
#                       No_of_Votes                           Gross
# 0  not currently in IMDB top 1000  not currently in IMDB top 1000
# 1  not currently in IMDB top 1000  not currently in IMDB top 1000
# 2  not currently in IMDB top 1000  not currently in IMDB top 1000
# 3  not currently in IMDB top 1000  not currently in IMDB top 1000
# 4  not currently in IMDB top 1000  not currently in IMDB top 1000

# %%
from settings import key

# %%
# Load
protocol = "postgresql"
username = "postgres"
host = 'localhost'
port = 5432
database_name = "Netflixmovies_db"

# %%
rds_connection_string = f'{protocol}://{username}:{key}@{host}:{port}/{database_name}'

# %%
engine = create_engine(rds_connection_string)

# %%
engine.table_names()
# Out:
# C:\Users\chisi\AppData\Local\Temp/ipykernel_26692/509743474.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['movies_db']

# %% [markdown]
# ##  Load DataFrames into database

# %%
 netflix_imdb1.to_sql(name='movies_db', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## Confirming data

# %%
pd.read_sql_query('select * from movies_db', con=engine).head()
# Out:
#      genre                  title         director  release_year    runtime  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson          2020     90 min
# 1  TV Show          Blood & Water             None          2021  2 Seasons
# 2  TV Show              Ganglands  Julien Leclercq          2021   1 Season
# 3  TV Show  Jailbirds New Orleans             None          2021   1 Season
# 4  TV Show           Kota Factory             None          2021  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                             overview  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
#
#                       IMDB_Rating                      Meta_score  \
# 0  not currently in IMDB top 1000  not currently in IMDB top 1000
# 1  not currently in IMDB top 1000  not currently in IMDB top 1000
# 2  not currently in IMDB top 1000  not currently in IMDB top 1000
# 3  not currently in IMDB top 1000  not currently in IMDB top 1000
# 4  not currently in IMDB top 1000  not currently in IMDB top 1000
#
#                       No_of_Votes                           Gross
# 0  not currently in IMDB top 1000  not currently in IMDB top 1000
# 1  not currently in IMDB top 1000  not currently in IMDB top 1000
# 2  not currently in IMDB top 1000  not currently in IMDB top 1000
# 3  not currently in IMDB top 1000  not currently in IMDB top 1000
# 4  not currently in IMDB top 1000  not currently in IMDB top 1000
